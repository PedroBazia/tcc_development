# %%
#importing libraries
import pandas as pd


df = pd.read_csv('DataFrame.csv', sep= ';')


df.head(10)
# Out:
#      Data   Imp-Total $  Imp_Bens_capital _$  Imp-Bens intermediarios $  \
# 0  jan/04  4.207687e+09          432475957.0               2.776454e+09
# 1  fev/04  3.748677e+09          466143181.0               2.487598e+09
# 2  mar/04  5.336953e+09          576749464.0               3.601074e+09
# 3  abr/04  4.627585e+09          551587540.0               2.937529e+09
# 4  mai/04  4.830229e+09          550615137.0               2.960862e+09
# 5  jun/04  5.523155e+09          544263938.0               3.543236e+09
# 6  jul/04  5.522543e+09          558319960.0               3.524076e+09
# 7  ago/04  5.617646e+09          595847802.0               3.651285e+09
# 8  set/04  5.744524e+09          582877592.0               3.789529e+09
# 9  out/04  5.841240e+09          568220075.0               3.609871e+09
#
#    Imp-Bens de consumo($)  Imp-Bens de consumo duraveis($)  \
# 0             341810085.0                       76750840.0
# ...

# %%
len(df)
# Out:
# 188

# %%
df.describe()
# Out:
#         Imp-Total $  Imp_Bens_capital _$  Imp-Bens intermediarios $  \
# count  1.870000e+02         1.870000e+02               1.870000e+02
# mean   1.332383e+10         1.768298e+09               7.710505e+09
# std    4.780350e+09         7.932762e+08               2.491467e+09
# min    3.748677e+09         4.324760e+08               2.487598e+09
# 25%    1.018302e+10         1.215960e+09               5.891912e+09
# 50%    1.310464e+10         1.665565e+09               7.949776e+09
# 75%    1.745000e+10         2.421851e+09               9.713331e+09
# max    2.304960e+10         4.768388e+09               1.258989e+10
#
#        Imp-Bens de consumo($)  Imp-Bens de consumo duraveis($)  \
# count            1.870000e+02                     1.870000e+02
# mean             1.872230e+09                     6.071424e+08
# std              8.162110e+08                     3.539616e+08
# min              3.418101e+08                     7.675084e+07
# ...

# %%
df.corr()
# Out:
#                                                     Imp-Total $  \
# Imp-Total $                                            1.000000
# Imp_Bens_capital _$                                    0.902918
# Imp-Bens intermediarios $                              0.987728
# Imp-Bens de consumo($)                                 0.959482
# Imp-Bens de consumo duraveis($)                        0.883086
# Imp-Bens de consumo semiduraveis e nao duraveis...     0.898548
# Imp-Combustiveis e lubrificantes(US$)                  0.860845
# Imp - Bens nao especificados anteriormente(US$)        0.204441
# Exp-Total(US$)                                         0.896700
# Exp- Prod. basicos(US$)                                0.863628
# Exp-Prod. Semimanufaturados(US$)                       0.835540
# Exp-Prod. Manufaturados(US$)                           0.700580
# PIB-mensal(MU$)                                        0.928835
# credito(MR$)                                           0.588896
# ...

# %%
df['Exp-Total(US$)'].plot.kde()

# %%
df.plot.line(x='Data', y=['Exp-Total(US$)'])

# %%
df.plot.line(x='Data', y=['Imp-Total $', 'Exp-Total(US$)'])

# %%
df.plot.line(x='Data', y=['Div Publica(MR$)', 'credito(MR$)' ])

# %%
df.plot.line(x='Data', y=['Div Pub(%PIB)'])

# %%
df.plot.line(x='Data', y=['Infl-IPCA'])

# %%
df.plot.barh(x='Data', y=['Infl-IPCA', 'Infl- IGPM'])

# %%
df.plot.line(x='Data', y=['dolar'], color='green')

# %%
df.plot.line(x='Data', y=['ind-geral'], color='red')

# %%
df.plot.line(x='Data', y=['Bovespa'])
