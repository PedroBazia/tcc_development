# %%
#importing libraries
import pandas as pd


df = pd.read_csv('DataFrame.csv', sep= ';')
df.set_index('Data',inplace=True)

df.head(10)
# Out:
#              Imp-Total $  Imp_Bens_capital _$  Imp-Bens intermediarios $  \
# Data
# 01/01/2004  4.207687e+09          432475957.0               2.776454e+09
# 01/02/2004  3.748677e+09          466143181.0               2.487598e+09
# 01/03/2004  5.336953e+09          576749464.0               3.601074e+09
# 01/04/2004  4.627585e+09          551587540.0               2.937529e+09
# 01/05/2004  4.830229e+09          550615137.0               2.960862e+09
# 01/06/2004  5.523155e+09          544263938.0               3.543236e+09
# 01/07/2004  5.522543e+09          558319960.0               3.524076e+09
# 01/08/2004  5.617646e+09          595847802.0               3.651285e+09
# 01/09/2004  5.744524e+09          582877592.0               3.789529e+09
# 01/10/2004  5.841240e+09          568220075.0               3.609871e+09
#
#             Imp-Bens de consumo($)  Imp-Bens de consumo duraveis($)  \
# Data
# 01/01/2004             341810085.0                       76750840.0
# 01/02/2004             347762513.0                       85158820.0
# 01/03/2004             477420075.0                       85935799.0
# 01/04/2004             384876230.0                       85272331.0
# 01/05/2004             448812347.0                      102315374.0
# 01/06/2004             466606180.0                      108131010.0
# 01/07/2004             484082821.0                      107812514.0
# 01/08/2004             447089339.0                       82954678.0
# 01/09/2004             502824459.0                      107363751.0
# 01/10/2004             467807073.0                       98242113.0
#
#             Imp-Bens de consumo semiduraveis e nao duraveis(US$)  \
# Data
# 01/01/2004                                        265059245.0
# 01/02/2004                                        262603693.0
# 01/03/2004                                        391484276.0
# 01/04/2004                                        299603899.0
# 01/05/2004                                        346496973.0
# 01/06/2004                                        358475170.0
# 01/07/2004                                        376270307.0
# 01/08/2004                                        364134661.0
# 01/09/2004                                        395460708.0
# 01/10/2004                                        369564960.0
#
#             Imp-Combustiveis e lubrificantes(US$)  \
# Data
# 01/01/2004                           6.662848e+08
# 01/02/2004                           4.592204e+08
# 01/03/2004                           6.897806e+08
# 01/04/2004                           7.605004e+08
# 01/05/2004                           8.751321e+08
# 01/06/2004                           9.758392e+08
# 01/07/2004                           9.628637e+08
# 01/08/2004                           9.290273e+08
# 01/09/2004                           8.777511e+08
# 01/10/2004                           1.194450e+09
#
#             Imp - Bens nao especificados anteriormente(US$)  Exp-Total(US$)  \
# Data
# 01/01/2004                                          30629.0    5.786904e+09
# 01/02/2004                                         676026.0    5.715581e+09
# 01/03/2004                                         282987.0    7.907131e+09
# 01/04/2004                                         138012.0    6.581422e+09
# 01/05/2004                                          91827.0    7.930944e+09
# 01/06/2004                                         280363.0    9.306641e+09
# 01/07/2004                                         863548.0    8.962901e+09
# 01/08/2004                                         240264.0    9.051482e+09
# 01/09/2004                                         241413.0    8.912130e+09
# 01/10/2004                                         139148.0    8.835879e+09
#
#             Exp- Prod. basicos(US$)  Exp-Prod. Semimanufaturados(US$)  \
# Data
# 01/01/2004             1.740539e+09                      9.857317e+08
# 01/02/2004             1.618078e+09                      8.813332e+08
# 01/03/2004             2.452783e+09                      1.070027e+09
# 01/04/2004             1.898813e+09                      7.908747e+08
# 01/05/2004             2.577223e+09                      1.009689e+09
# 01/06/2004             3.381306e+09                      1.213030e+09
# 01/07/2004             2.778037e+09                      1.348031e+09
# 01/08/2004             2.966368e+09                      1.215139e+09
# 01/09/2004             2.654272e+09                      1.285028e+09
# 01/10/2004             2.303634e+09                      1.120670e+09
#
#             Exp-Prod. Manufaturados(US$)  PIB-mensal(MU$)  credito(MR$)  \
# Data
# 01/01/2004                  2.978528e+09          49802.0      417770.0
# 01/02/2004                  3.148654e+09          50345.0      420849.0
# 01/03/2004                  4.284993e+09          56809.0      423347.0
# 01/04/2004                  3.823522e+09          55324.0      435554.0
# 01/05/2004                  4.261516e+09          54872.0      445864.0
# 01/06/2004                  4.613620e+09          55580.0      452933.0
# 01/07/2004                  4.765906e+09          58082.0      457302.0
# 01/08/2004                  4.711744e+09          57685.0      464457.0
# 01/09/2004                  4.840346e+09          57115.0      473707.0
# 01/10/2004                  5.301900e+09          57839.0      487245.0
#
#             Infl- IGPM  Infl-IPCA  Div Publica(MR$)  Div publica(M$)  \
# Data
# 01/01/2004        0.88       0.76         917346.23        312011.91
# 01/02/2004        0.69       0.61         910484.19        312558.94
# 01/03/2004        1.13       0.47         913609.96        314192.85
# 01/04/2004        1.21       0.37         918095.92        311863.83
# 01/05/2004        1.31       0.51         941268.02        300888.03
# 01/06/2004        1.38       0.71         946539.21        304676.73
# 01/07/2004        1.31       0.91         944978.98        312286.51
# 01/08/2004        1.22       0.69         945701.39        322434.84
# 01/09/2004        0.69       0.33         942224.68        329702.81
# 01/10/2004        0.39       0.44         949353.89        332441.74
#
#             Div Pub(%PIB)
# Data
# 01/01/2004          71.59
# 01/02/2004          71.70
# 01/03/2004          72.19
# 01/04/2004          71.31
# 01/05/2004          70.69
# 01/06/2004          70.82
# 01/07/2004          69.53
# 01/08/2004          68.78
# 01/09/2004          68.60
# 01/10/2004          68.60

# %%
len(df)
# Out:
# 189

# %%
df.describe()
# Out:
#         Imp-Total $  Imp_Bens_capital _$  Imp-Bens intermediarios $  \
# count  1.880000e+02         1.870000e+02               1.870000e+02
# mean   1.332383e+10         1.768298e+09               7.710505e+09
# std    4.767551e+09         7.932762e+08               2.491467e+09
# min    3.748677e+09         4.324760e+08               2.487598e+09
# 25%    1.024560e+10         1.215960e+09               5.891912e+09
# 50%    1.311797e+10         1.665565e+09               7.949776e+09
# 75%    1.744871e+10         2.421851e+09               9.713331e+09
# max    2.304960e+10         4.768388e+09               1.258989e+10
#
#        Imp-Bens de consumo($)  Imp-Bens de consumo duraveis($)  \
# count            1.870000e+02                     1.870000e+02
# mean             1.872230e+09                     6.071424e+08
# std              8.162110e+08                     3.539616e+08
# min              3.418101e+08                     7.675084e+07
# 25%              1.288143e+09                     3.684172e+08
# 50%              1.985781e+09                     5.220119e+08
# 75%              2.565082e+09                     8.865883e+08
# max              3.734106e+09                     1.790963e+09
#
#        Imp-Bens de consumo semiduraveis e nao duraveis(US$)  \
# count                                       1.870000e+02
# mean                                        1.265088e+09
# std                                         5.236907e+08
# min                                         2.626037e+08
# 25%                                         8.161831e+08
# 50%                                         1.419520e+09
# 75%                                         1.687500e+09
# max                                         2.216173e+09
#
#        Imp-Combustiveis e lubrificantes(US$)  \
# count                           1.870000e+02
# mean                            1.967678e+09
# std                             9.450593e+08
# min                             4.592204e+08
# 25%                             1.240353e+09
# 50%                             1.703417e+09
# 75%                             2.523320e+09
# max                             4.941290e+09
#
#        Imp - Bens nao especificados anteriormente(US$)  Exp-Total(US$)  \
# count                                     1.870000e+02    1.870000e+02
# mean                                      6.722202e+06    1.601120e+10
# std                                       1.349988e+07    4.374266e+09
# min                                       3.062900e+04    5.715581e+09
# 25%                                       7.074520e+05    1.266230e+10
# 50%                                       2.223806e+06    1.612196e+10
# 75%                                       6.274734e+06    1.966561e+10
# max                                       8.630880e+07    2.614824e+10
#
#        Exp- Prod. basicos(US$)  Exp-Prod. Semimanufaturados(US$)  \
# count             1.870000e+02                      1.870000e+02
# mean              6.913263e+09                      2.184511e+09
# std               2.893707e+09                      5.945902e+08
# min               1.618078e+09                      7.908747e+08
# 25%               4.324628e+09                      1.793374e+09
# 50%               7.225353e+09                      2.274967e+09
# 75%               9.411081e+09                      2.625014e+09
# max               1.276169e+10                      3.935309e+09
#
#        Exp-Prod. Manufaturados(US$)  PIB-mensalUS$ (milhoes)  \
# count                  1.870000e+02               187.000000
# mean                   6.582040e+09            150981.871658
# std                    1.186629e+09             47614.681421
# min                    2.978528e+09             49802.000000
# 25%                    5.803568e+09            122808.500000
# 50%                    6.688567e+09            151379.000000
# 75%                    7.349830e+09            191153.000000
# max                    9.828673e+09            227371.000000
#
#        creditoR$(milhoes)
# count        1.870000e+02
# mean         1.941088e+06
# std          1.021304e+06
# min          4.177700e+05
# 25%          9.313685e+05
# 50%          1.950658e+06
# 75%          3.070865e+06
# max          3.296449e+06

# %%
df['Exp-Total(US$)'].plot.kde()

# %%
df.corr()
# Out:
#                                                     Imp-Total $  \
# Imp-Total $                                            1.000000
# Imp_Bens_capital _$                                    0.902918
# Imp-Bens intermediarios $                              0.987728
# Imp-Bens de consumo($)                                 0.959482
# Imp-Bens de consumo duraveis($)                        0.883086
# Imp-Bens de consumo semiduraveis e nao duraveis...     0.898548
# Imp-Combustiveis e lubrificantes(US$)                  0.860845
# Imp - Bens nao especificados anteriormente(US$)        0.204441
# Exp-Total(US$)                                         0.896700
# Exp- Prod. basicos(US$)                                0.863628
# Exp-Prod. Semimanufaturados(US$)                       0.835540
# Exp-Prod. Manufaturados(US$)                           0.700580
# PIB-mensal(MU$)                                        0.928835
# credito(MR$)                                           0.588896
# Infl- IGPM                                             0.040694
# Infl-IPCA                                              0.010862
# Div Publica(MR$)                                       0.275625
# Div publica(M$)                                        0.655050
# Div Pub(%PIB)                                         -0.259479
#
#                                                     Imp_Bens_capital _$  \
# Imp-Total $                                                    0.902918
# Imp_Bens_capital _$                                            1.000000
# Imp-Bens intermediarios $                                      0.865058
# Imp-Bens de consumo($)                                         0.853648
# Imp-Bens de consumo duraveis($)                                0.791070
# Imp-Bens de consumo semiduraveis e nao duraveis...             0.795791
# Imp-Combustiveis e lubrificantes(US$)                          0.704157
# Imp - Bens nao especificados anteriormente(US$)                0.167989
# Exp-Total(US$)                                                 0.799851
# Exp- Prod. basicos(US$)                                        0.779207
# Exp-Prod. Semimanufaturados(US$)                               0.712178
# Exp-Prod. Manufaturados(US$)                                   0.632118
# PIB-mensal(MU$)                                                0.813789
# credito(MR$)                                                   0.540821
# Infl- IGPM                                                     0.022258
# Infl-IPCA                                                     -0.000659
# Div Publica(MR$)                                               0.273821
# Div publica(M$)                                                0.574797
# Div Pub(%PIB)                                                 -0.188400
#
#                                                     Imp-Bens intermediarios $  \
# Imp-Total $                                                          0.987728
# Imp_Bens_capital _$                                                  0.865058
# Imp-Bens intermediarios $                                            1.000000
# Imp-Bens de consumo($)                                               0.955472
# Imp-Bens de consumo duraveis($)                                      0.850191
# Imp-Bens de consumo semiduraveis e nao duraveis...                   0.914531
# Imp-Combustiveis e lubrificantes(US$)                                0.801613
# Imp - Bens nao especificados anteriormente(US$)                      0.207806
# Exp-Total(US$)                                                       0.911815
# Exp- Prod. basicos(US$)                                              0.883099
# Exp-Prod. Semimanufaturados(US$)                                     0.862020
# Exp-Prod. Manufaturados(US$)                                         0.695714
# PIB-mensal(MU$)                                                      0.927850
# credito(MR$)                                                         0.632004
# Infl- IGPM                                                           0.057535
# Infl-IPCA                                                           -0.009248
# Div Publica(MR$)                                                     0.340381
# Div publica(M$)                                                      0.695402
# Div Pub(%PIB)                                                       -0.198244
#
#                                                     Imp-Bens de consumo($)  \
# Imp-Total $                                                       0.959482
# Imp_Bens_capital _$                                               0.853648
# Imp-Bens intermediarios $                                         0.955472
# Imp-Bens de consumo($)                                            1.000000
# Imp-Bens de consumo duraveis($)                                   0.895161
# Imp-Bens de consumo semiduraveis e nao duraveis...                0.953537
# Imp-Combustiveis e lubrificantes(US$)                             0.746846
# Imp - Bens nao especificados anteriormente(US$)                   0.246141
# Exp-Total(US$)                                                    0.878908
# Exp- Prod. basicos(US$)                                           0.860419
# Exp-Prod. Semimanufaturados(US$)                                  0.847704
# Exp-Prod. Manufaturados(US$)                                      0.636642
# PIB-mensal(MU$)                                                   0.956548
# credito(MR$)                                                      0.674342
# Infl- IGPM                                                        0.029924
# Infl-IPCA                                                         0.058292
# Div Publica(MR$)                                                  0.340393
# Div publica(M$)                                                   0.694011
# Div Pub(%PIB)                                                    -0.202384
#
#                                                     Imp-Bens de consumo duraveis($)  \
# Imp-Total $                                                                0.883086
# Imp_Bens_capital _$                                                        0.791070
# Imp-Bens intermediarios $                                                  0.850191
# Imp-Bens de consumo($)                                                     0.895161
# Imp-Bens de consumo duraveis($)                                            1.000000
# Imp-Bens de consumo semiduraveis e nao duraveis...                         0.719277
# Imp-Combustiveis e lubrificantes(US$)                                      0.782866
# Imp - Bens nao especificados anteriormente(US$)                            0.140866
# Exp-Total(US$)                                                             0.766043
# Exp- Prod. basicos(US$)                                                    0.716608
# Exp-Prod. Semimanufaturados(US$)                                           0.720563
# Exp-Prod. Manufaturados(US$)                                               0.638400
# PIB-mensal(MU$)                                                            0.876590
# credito(MR$)                                                               0.310576
# Infl- IGPM                                                                 0.057915
# Infl-IPCA                                                                  0.059100
# Div Publica(MR$)                                                          -0.021612
# Div publica(M$)                                                            0.506389
# Div Pub(%PIB)                                                             -0.477720
#
#                                                     Imp-Bens de consumo semiduraveis e nao duraveis(US$)  \
# Imp-Total $                                                                                  0.898548
# Imp_Bens_capital _$                                                                          0.795791
# Imp-Bens intermediarios $                                                                    0.914531
# Imp-Bens de consumo($)                                                                       0.953537
# Imp-Bens de consumo duraveis($)                                                              0.719277
# Imp-Bens de consumo semiduraveis e nao duraveis...                                           1.000000
# Imp-Combustiveis e lubrificantes(US$)                                                        0.634878
# Imp - Bens nao especificados anteriormente(US$)                                              0.288419
# Exp-Total(US$)                                                                               0.852077
# Exp- Prod. basicos(US$)                                                                      0.856673
# Exp-Prod. Semimanufaturados(US$)                                                             0.834182
# Exp-Prod. Manufaturados(US$)                                                                 0.560760
# PIB-mensal(MU$)                                                                              0.898366
# credito(MR$)                                                                                 0.841095
# Infl- IGPM                                                                                   0.007493
# Infl-IPCA                                                                                    0.050907
# Div Publica(MR$)                                                                             0.545136
# Div publica(M$)                                                                              0.739401
# Div Pub(%PIB)                                                                                0.007460
#
#                                                     Imp-Combustiveis e lubrificantes(US$)  \
# Imp-Total $                                                                      0.860845
# Imp_Bens_capital _$                                                              0.704157
# Imp-Bens intermediarios $                                                        0.801613
# Imp-Bens de consumo($)                                                           0.746846
# Imp-Bens de consumo duraveis($)                                                  0.782866
# Imp-Bens de consumo semiduraveis e nao duraveis...                               0.634878
# Imp-Combustiveis e lubrificantes(US$)                                            1.000000
# Imp - Bens nao especificados anteriormente(US$)                                  0.117017
# Exp-Total(US$)                                                                   0.694765
# Exp- Prod. basicos(US$)                                                          0.636376
# Exp-Prod. Semimanufaturados(US$)                                                 0.617177
# Exp-Prod. Manufaturados(US$)                                                     0.625089
# PIB-mensal(MU$)                                                                  0.735955
# credito(MR$)                                                                     0.268728
# Infl- IGPM                                                                       0.008977
# Infl-IPCA                                                                        0.029026
# Div Publica(MR$)                                                                -0.032163
# Div publica(M$)                                                                  0.391623
# Div Pub(%PIB)                                                                   -0.457762
#
#                                                     Imp - Bens nao especificados anteriormente(US$)  \
# Imp-Total $                                                                                0.204441
# Imp_Bens_capital _$                                                                        0.167989
# Imp-Bens intermediarios $                                                                  0.207806
# Imp-Bens de consumo($)                                                                     0.246141
# Imp-Bens de consumo duraveis($)                                                            0.140866
# Imp-Bens de consumo semiduraveis e nao duraveis...                                         0.288419
# Imp-Combustiveis e lubrificantes(US$)                                                      0.117017
# Imp - Bens nao especificados anteriormente(US$)                                            1.000000
# Exp-Total(US$)                                                                             0.217123
# Exp- Prod. basicos(US$)                                                                    0.225992
# Exp-Prod. Semimanufaturados(US$)                                                           0.228125
# Exp-Prod. Manufaturados(US$)                                                               0.116016
# PIB-mensal(MU$)                                                                            0.223943
# credito(MR$)                                                                               0.325153
# Infl- IGPM                                                                                -0.023206
# Infl-IPCA                                                                                 -0.008225
# Div Publica(MR$)                                                                           0.231580
# Div publica(M$)                                                                            0.190983
# Div Pub(%PIB)                                                                              0.101120
#
#                                                     Exp-Total(US$)  \
# Imp-Total $                                               0.896700
# Imp_Bens_capital _$                                       0.799851
# Imp-Bens intermediarios $                                 0.911815
# Imp-Bens de consumo($)                                    0.878908
# Imp-Bens de consumo duraveis($)                           0.766043
# Imp-Bens de consumo semiduraveis e nao duraveis...        0.852077
# Imp-Combustiveis e lubrificantes(US$)                     0.694765
# Imp - Bens nao especificados anteriormente(US$)           0.217123
# Exp-Total(US$)                                            1.000000
# Exp- Prod. basicos(US$)                                   0.964333
# Exp-Prod. Semimanufaturados(US$)                          0.907870
# Exp-Prod. Manufaturados(US$)                              0.807980
# PIB-mensal(MU$)                                           0.869935
# credito(MR$)                                              0.653642
# Infl- IGPM                                               -0.014437
# Infl-IPCA                                                -0.153057
# Div Publica(MR$)                                          0.476794
# Div publica(M$)                                           0.770114
# Div Pub(%PIB)                                             0.013170
#
#                                                     Exp- Prod. basicos(US$)  \
# Imp-Total $                                                        0.863628
# Imp_Bens_capital _$                                                0.779207
# Imp-Bens intermediarios $                                          0.883099
# Imp-Bens de consumo($)                                             0.860419
# Imp-Bens de consumo duraveis($)                                    0.716608
# Imp-Bens de consumo semiduraveis e nao duraveis...                 0.856673
# Imp-Combustiveis e lubrificantes(US$)                              0.636376
# Imp - Bens nao especificados anteriormente(US$)                    0.225992
# Exp-Total(US$)                                                     0.964333
# Exp- Prod. basicos(US$)                                            1.000000
# Exp-Prod. Semimanufaturados(US$)                                   0.836442
# Exp-Prod. Manufaturados(US$)                                       0.634834
# PIB-mensal(MU$)                                                    0.853807
# credito(MR$)                                                       0.723405
# Infl- IGPM                                                         0.000741
# Infl-IPCA                                                         -0.118858
# Div Publica(MR$)                                                   0.552660
# Div publica(M$)                                                    0.776875
# Div Pub(%PIB)                                                      0.099474
#
#                                                     Exp-Prod. Semimanufaturados(US$)  \
# Imp-Total $                                                                 0.835540
# Imp_Bens_capital _$                                                         0.712178
# Imp-Bens intermediarios $                                                   0.862020
# Imp-Bens de consumo($)                                                      0.847704
# Imp-Bens de consumo duraveis($)                                             0.720563
# Imp-Bens de consumo semiduraveis e nao duraveis...                          0.834182
# Imp-Combustiveis e lubrificantes(US$)                                       0.617177
# Imp - Bens nao especificados anteriormente(US$)                             0.228125
# Exp-Total(US$)                                                              0.907870
# Exp- Prod. basicos(US$)                                                     0.836442
# Exp-Prod. Semimanufaturados(US$)                                            1.000000
# Exp-Prod. Manufaturados(US$)                                                0.734175
# PIB-mensal(MU$)                                                             0.835523
# credito(MR$)                                                                0.639509
# Infl- IGPM                                                                  0.016370
# Infl-IPCA                                                                  -0.081839
# Div Publica(MR$)                                                            0.473256
# Div publica(M$)                                                             0.775358
# Div Pub(%PIB)                                                               0.023057
#
#                                                     Exp-Prod. Manufaturados(US$)  \
# Imp-Total $                                                             0.700580
# Imp_Bens_capital _$                                                     0.632118
# Imp-Bens intermediarios $                                               0.695714
# Imp-Bens de consumo($)                                                  0.636642
# Imp-Bens de consumo duraveis($)                                         0.638400
# Imp-Bens de consumo semiduraveis e nao duraveis...                      0.560760
# Imp-Combustiveis e lubrificantes(US$)                                   0.625089
# Imp - Bens nao especificados anteriormente(US$)                         0.116016
# Exp-Total(US$)                                                          0.807980
# Exp- Prod. basicos(US$)                                                 0.634834
# Exp-Prod. Semimanufaturados(US$)                                        0.734175
# Exp-Prod. Manufaturados(US$)                                            1.000000
# PIB-mensal(MU$)                                                         0.624107
# credito(MR$)                                                            0.282539
# Infl- IGPM                                                             -0.060890
# Infl-IPCA                                                              -0.242715
# Div Publica(MR$)                                                        0.174983
# Div publica(M$)                                                         0.511968
# Div Pub(%PIB)                                                          -0.152709
#
#                                                     PIB-mensal(MU$)  \
# Imp-Total $                                                0.928835
# Imp_Bens_capital _$                                        0.813789
# Imp-Bens intermediarios $                                  0.927850
# Imp-Bens de consumo($)                                     0.956548
# Imp-Bens de consumo duraveis($)                            0.876590
# Imp-Bens de consumo semiduraveis e nao duraveis...         0.898366
# Imp-Combustiveis e lubrificantes(US$)                      0.735955
# Imp - Bens nao especificados anteriormente(US$)            0.223943
# Exp-Total(US$)                                             0.869935
# Exp- Prod. basicos(US$)                                    0.853807
# Exp-Prod. Semimanufaturados(US$)                           0.835523
# Exp-Prod. Manufaturados(US$)                               0.624107
# PIB-mensal(MU$)                                            1.000000
# credito(MR$)                                               0.641079
# Infl- IGPM                                                -0.025623
# Infl-IPCA                                                  0.001375
# Div Publica(MR$)                                           0.325631
# Div publica(M$)                                            0.742124
# Div Pub(%PIB)                                             -0.224115
#
#                                                     credito(MR$)  Infl- IGPM  \
# Imp-Total $                                             0.588896    0.040694
# Imp_Bens_capital _$                                     0.540821    0.022258
# Imp-Bens intermediarios $                               0.632004    0.057535
# Imp-Bens de consumo($)                                  0.674342    0.029924
# Imp-Bens de consumo duraveis($)                         0.310576    0.057915
# Imp-Bens de consumo semiduraveis e nao duraveis...      0.841095    0.007493
# Imp-Combustiveis e lubrificantes(US$)                   0.268728    0.008977
# Imp - Bens nao especificados anteriormente(US$)         0.325153   -0.023206
# Exp-Total(US$)                                          0.653642   -0.014437
# Exp- Prod. basicos(US$)                                 0.723405    0.000741
# Exp-Prod. Semimanufaturados(US$)                        0.639509    0.016370
# Exp-Prod. Manufaturados(US$)                            0.282539   -0.060890
# PIB-mensal(MU$)                                         0.641079   -0.025623
# credito(MR$)                                            1.000000   -0.005487
# Infl- IGPM                                             -0.005487    1.000000
# Infl-IPCA                                               0.050083    0.486841
# Div Publica(MR$)                                        0.833787   -0.035474
# Div publica(M$)                                         0.718662   -0.081865
# Div Pub(%PIB)                                           0.417740    0.007640
#
#                                                     Infl-IPCA  \
# Imp-Total $                                          0.010862
# Imp_Bens_capital _$                                 -0.000659
# Imp-Bens intermediarios $                           -0.009248
# Imp-Bens de consumo($)                               0.058292
# Imp-Bens de consumo duraveis($)                      0.059100
# Imp-Bens de consumo semiduraveis e nao duraveis...   0.050907
# Imp-Combustiveis e lubrificantes(US$)                0.029026
# Imp - Bens nao especificados anteriormente(US$)     -0.008225
# Exp-Total(US$)                                      -0.153057
# Exp- Prod. basicos(US$)                             -0.118858
# Exp-Prod. Semimanufaturados(US$)                    -0.081839
# Exp-Prod. Manufaturados(US$)                        -0.242715
# PIB-mensal(MU$)                                      0.001375
# credito(MR$)                                         0.050083
# Infl- IGPM                                           0.486841
# Infl-IPCA                                            1.000000
# Div Publica(MR$)                                    -0.156281
# Div publica(M$)                                     -0.192314
# Div Pub(%PIB)                                       -0.198854
#
#                                                     Div Publica(MR$)  \
# Imp-Total $                                                 0.275625
# Imp_Bens_capital _$                                         0.273821
# Imp-Bens intermediarios $                                   0.340381
# Imp-Bens de consumo($)                                      0.340393
# Imp-Bens de consumo duraveis($)                            -0.021612
# Imp-Bens de consumo semiduraveis e nao duraveis...          0.545136
# Imp-Combustiveis e lubrificantes(US$)                      -0.032163
# Imp - Bens nao especificados anteriormente(US$)             0.231580
# Exp-Total(US$)                                              0.476794
# Exp- Prod. basicos(US$)                                     0.552660
# Exp-Prod. Semimanufaturados(US$)                            0.473256
# Exp-Prod. Manufaturados(US$)                                0.174983
# PIB-mensal(MU$)                                             0.325631
# credito(MR$)                                                0.833787
# Infl- IGPM                                                 -0.035474
# Infl-IPCA                                                  -0.156281
# Div Publica(MR$)                                            1.000000
# Div publica(M$)                                             0.751419
# Div Pub(%PIB)                                               0.813278
#
#                                                     Div publica(M$)  \
# Imp-Total $                                                0.655050
# Imp_Bens_capital _$                                        0.574797
# Imp-Bens intermediarios $                                  0.695402
# Imp-Bens de consumo($)                                     0.694011
# Imp-Bens de consumo duraveis($)                            0.506389
# Imp-Bens de consumo semiduraveis e nao duraveis...         0.739401
# Imp-Combustiveis e lubrificantes(US$)                      0.391623
# Imp - Bens nao especificados anteriormente(US$)            0.190983
# Exp-Total(US$)                                             0.770114
# Exp- Prod. basicos(US$)                                    0.776875
# Exp-Prod. Semimanufaturados(US$)                           0.775358
# Exp-Prod. Manufaturados(US$)                               0.511968
# PIB-mensal(MU$)                                            0.742124
# credito(MR$)                                               0.718662
# Infl- IGPM                                                -0.081865
# Infl-IPCA                                                 -0.192314
# Div Publica(MR$)                                           0.751419
# Div publica(M$)                                            1.000000
# Div Pub(%PIB)                                              0.365853
#
#                                                     Div Pub(%PIB)
# Imp-Total $                                             -0.259479
# Imp_Bens_capital _$                                     -0.188400
# Imp-Bens intermediarios $                               -0.198244
# Imp-Bens de consumo($)                                  -0.202384
# Imp-Bens de consumo duraveis($)                         -0.477720
# Imp-Bens de consumo semiduraveis e nao duraveis...       0.007460
# Imp-Combustiveis e lubrificantes(US$)                   -0.457762
# Imp - Bens nao especificados anteriormente(US$)          0.101120
# Exp-Total(US$)                                           0.013170
# Exp- Prod. basicos(US$)                                  0.099474
# Exp-Prod. Semimanufaturados(US$)                         0.023057
# Exp-Prod. Manufaturados(US$)                            -0.152709
# PIB-mensal(MU$)                                         -0.224115
# credito(MR$)                                             0.417740
# Infl- IGPM                                               0.007640
# Infl-IPCA                                               -0.198854
# Div Publica(MR$)                                         0.813278
# Div publica(M$)                                          0.365853
# Div Pub(%PIB)                                            1.000000

# %%
df.plot.line(x='Data', y=['Exp-Total(US$)'])

# %%
df.plot.line(x='Data', y=['Imp-Total $', 'Exp-Total(US$)'])

# %%
df.plot.line(x='Data', y=['Div Pub(%PIB)'])

# %%
df.plot.line(x='Data', y=['Infl-IPCA'])
